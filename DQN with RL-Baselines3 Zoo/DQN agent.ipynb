# %% [markdown]
# ### Installing RL-Baselines3 Zoo

# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# fatal: destination path 'rl-baselines3-zoo' already exists and is not an empty directory.

# %%
# %cd rl-baselines3-zoo
# Out:
# /home/rram12/R_files/R/ML/RL/HF-DRL/unit3/rl-baselines3-zoo

# %%
# !pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -yglet (/home/rram12/anaconda3/envs/rl/lib/python3.10/site-packages)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'rl-baselines3-zoo/requirements.txt'
# WARNING: Ignoring invalid distribution -yglet (/home/rram12/anaconda3/envs/rl/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yglet (/home/rram12/anaconda3/envs/rl/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -yglet (/home/rram12/anaconda3/envs/rl/lib/python3.10/site-packages)

# %% [markdown]
# ### Training the agent

# %%
# !python train.py --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 3324772530
# Loading hyperparameters from: hyperparams/dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 88       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 1012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.74e+03 |
# |    ep_rew_mean      | 265      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 157      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 1956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 192      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 2505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.44e+03 |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 231      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 262      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 3756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 300      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.33e+03 |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 340      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 5435     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 360      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 5956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 382      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 6531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 412      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 441      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 8337     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 456      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 472      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 9450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 487      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 10065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 510      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 11010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 531      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 11970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.29e+03 |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 543      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 12587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 550      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 12952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 563      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 13689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 574      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 584      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 14960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 597      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 15761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 606      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 16458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 611      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 17053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 621      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 17960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 631      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 18909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 637      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 644      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 20039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 651      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 20775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 661      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 21998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 665      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 22500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 671      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 23108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 677      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 23859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 681      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 24353    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=141.00 +/- 56.07
# Episode length: 2257.60 +/- 385.28
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.26e+03 |
# |    mean_reward      | 141      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 503      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 25382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 508      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 25976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 517      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 26964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 524      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 27743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 529      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 28282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 534      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 28846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 541      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 29667    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 546      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 30385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 551      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 31003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 557      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 31758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 565      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 32707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 569      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 33358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 575      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 34108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 579      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 34658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 584      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 35434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 591      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 36509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 594      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 36947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 596      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 37313    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.625    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 599      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 37848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 603      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 38528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 605      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 38914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 611      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 40071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 615      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 40816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 617      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 41177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 620      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 41706    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 622      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 42170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 626      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 42959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 629      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 43566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 634      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 44527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 637      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 45339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 639      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 45732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 642      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 46407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 644      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 47046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 647      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 47802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 651      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 48629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 652      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 49761    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=188.00 +/- 43.89
# Episode length: 2626.00 +/- 184.68
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.63e+03 |
# |    mean_reward      | 188      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.501    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 615      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 50438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 618      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 51259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 620      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 51815    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 623      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 52662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 625      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 53279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 627      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 53908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 630      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 54633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 632      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 55202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 634      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 55938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 635      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 56455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 637      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 57122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 639      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 57649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 641      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 58400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.414    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 644      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 59185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 646      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 59883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 648      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 60369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 650      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 61118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 652      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 61720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 653      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 62204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 653      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 62735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 652      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 63118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 650      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 63612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.363    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 649      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 64293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 650      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 65189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 652      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 65982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 653      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 66789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 654      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 67391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 656      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 68229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 658      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 68858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 658      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 69367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 658      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 70058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 660      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 70774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.295    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 661      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 71236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 663      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 71965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 665      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 73003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 667      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 73876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 668      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 74458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 669      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 74938    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=127.00 +/- 41.55
# Episode length: 2194.40 +/- 242.10
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.19e+03 |
# |    mean_reward      | 127      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 645      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 75481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 646      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 76007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 645      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 76730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.233    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 647      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 77469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.226    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 648      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 78190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 649      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 78990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 650      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 79391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.205    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 652      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 80352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 653      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 80825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 654      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 81414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 154      |
# ...
# |    loss             | 0.0114   |
# |    n_updates        | 214277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4016     |
# |    fps              | 189      |
# |    time_elapsed     | 5056     |
# |    total_timesteps  | 957662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 214415   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 525      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4020     |
# |    fps              | 189      |
# |    time_elapsed     | 5062     |
# |    total_timesteps  | 958732   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 214682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4024     |
# |    fps              | 189      |
# |    time_elapsed     | 5068     |
# |    total_timesteps  | 959933   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 214983   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4028     |
# |    fps              | 189      |
# |    time_elapsed     | 5071     |
# |    total_timesteps  | 960596   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 215148   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 517      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 189      |
# |    time_elapsed     | 5077     |
# |    total_timesteps  | 961830   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 215457   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 189      |
# |    time_elapsed     | 5085     |
# |    total_timesteps  | 963333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00991  |
# |    n_updates        | 215833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 189      |
# |    time_elapsed     | 5096     |
# |    total_timesteps  | 965606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0085   |
# |    n_updates        | 216401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 516      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 189      |
# |    time_elapsed     | 5101     |
# |    total_timesteps  | 966571   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 216642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 512      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 189      |
# |    time_elapsed     | 5114     |
# |    total_timesteps  | 969247   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 217311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 514      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 189      |
# |    time_elapsed     | 5118     |
# |    total_timesteps  | 970078   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 217519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 515      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 189      |
# |    time_elapsed     | 5125     |
# |    total_timesteps  | 971552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00982  |
# |    n_updates        | 217887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 513      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 189      |
# |    time_elapsed     | 5131     |
# |    total_timesteps  | 972633   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 218158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 517      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 189      |
# |    time_elapsed     | 5139     |
# |    total_timesteps  | 974272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 218567   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=428.00 +/- 121.43
# Episode length: 3739.80 +/- 816.61
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.74e+03 |
# |    mean_reward      | 428      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 516      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 189      |
# |    time_elapsed     | 5155     |
# |    total_timesteps  | 975313   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 218828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 516      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 189      |
# |    time_elapsed     | 5160     |
# |    total_timesteps  | 976404   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 219100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 525      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 189      |
# |    time_elapsed     | 5176     |
# |    total_timesteps  | 979832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 219957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 189      |
# |    time_elapsed     | 5181     |
# |    total_timesteps  | 980948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 220236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 189      |
# |    time_elapsed     | 5187     |
# |    total_timesteps  | 982132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 220532   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 189      |
# |    time_elapsed     | 5193     |
# |    total_timesteps  | 983526   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 220881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 189      |
# |    time_elapsed     | 5204     |
# |    total_timesteps  | 985845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 221461   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 534      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 189      |
# |    time_elapsed     | 5212     |
# |    total_timesteps  | 987749   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 221937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 540      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 189      |
# |    time_elapsed     | 5222     |
# |    total_timesteps  | 990061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 222515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 535      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 189      |
# |    time_elapsed     | 5226     |
# |    total_timesteps  | 990886   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 222721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4108     |
# |    fps              | 189      |
# |    time_elapsed     | 5233     |
# |    total_timesteps  | 992370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00678  |
# |    n_updates        | 223092   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 535      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4112     |
# |    fps              | 189      |
# |    time_elapsed     | 5241     |
# |    total_timesteps  | 994127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 223531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 539      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4116     |
# |    fps              | 189      |
# |    time_elapsed     | 5247     |
# |    total_timesteps  | 995394   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00885  |
# |    n_updates        | 223848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 545      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4120     |
# |    fps              | 189      |
# |    time_elapsed     | 5256     |
# |    total_timesteps  | 997469   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 224367   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92e+03 |
# |    ep_rew_mean      | 548      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4124     |
# |    fps              | 189      |
# |    time_elapsed     | 5263     |
# |    total_timesteps  | 999014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 224753   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=767.00 +/- 249.21
# Episode length: 4871.40 +/- 1034.33
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.87e+03 |
# |    mean_reward      | 767      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00987  |
# |    n_updates        | 224999   |
# ----------------------------------
# New best mean reward!
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_4

# %% [markdown]
# ### Evaluating the agent

# %%
# !python enjoy.py  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Atari Episode Score: 800.00
# Atari Episode Length 4806
# Atari Episode Score: 570.00
# Atari Episode Length 4080
# Atari Episode Score: 390.00
# Atari Episode Length 2678
# Atari Episode Score: 425.00
# Atari Episode Length 3600
# Atari Episode Score: 515.00
# Atari Episode Length 5045
